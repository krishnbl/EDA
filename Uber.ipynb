# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from colorama import Fore,Style

# %%
df=pd.read_csv('Uberdataset.csv')
df
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                   STOP    MILES          PURPOSE
# 0          Fort Pierce      5.1   Meal/Entertain
# 1          Fort Pierce      5.0              NaN
# 2          Fort Pierce      4.8  Errand/Supplies
# 3          Fort Pierce      4.7          Meeting
# 4      West Palm Beach     63.7   Customer Visit
# ...                ...      ...              ...
# 1151  Unknown Location      3.9   Temporary Site
# 1152  Unknown Location     16.2          Meeting
# 1153           Gampaha      6.4   Temporary Site
# 1154         Ilukwatta     48.2   Temporary Site
# 1155               NaN  12204.7              NaN
#
# [1156 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  1156 non-null   object
#  1   END_DATE    1155 non-null   object
#  2   CATEGORY    1155 non-null   object
#  3   START       1155 non-null   object
#  4   STOP        1155 non-null   object
#  5   MILES       1156 non-null   float64
#  6   PURPOSE     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
df.columns
# Out:
# Index(['START_DATE', 'END_DATE', 'CATEGORY', 'START', 'STOP', 'MILES',
#        'PURPOSE'],
#       dtype='object')

# %%
print(f"{Fore.GREEN}The Shape of Dataset is: {df.shape}.{Style.RESET_ALL}")
# Out:
# The Shape of Dataset is: (1156, 7).

# %%
print(f"{Fore.RED}information of Featires in Dataset: \n.{Style.RESET_ALL}")
df.info()
# Out:
# information of Featires in Dataset:
# .
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  1156 non-null   object
#  1   END_DATE    1155 non-null   object
#  2   CATEGORY    1155 non-null   object
#  3   START       1155 non-null   object
#  4   STOP        1155 non-null   object
#  5   MILES       1156 non-null   float64
#  6   PURPOSE     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
print(f"{Fore.RED}The statastical description of 'Miles': \n.{Style.RESET_ALL}")
df.describe()
# Out:
# The statastical description of 'Miles':
# .
#               MILES
# count   1156.000000
# mean      21.115398
# std      359.299007
# min        0.500000
# 25%        2.900000
# 50%        6.000000
# 75%       10.400000
# max    12204.700000

# %%
print(f"{Fore.RED}The duplicated in daaset: \n.{Style.RESET_ALL}")
df[df.duplicated()]
# Out:
# The duplicated in daaset:
# .
#           START_DATE         END_DATE  CATEGORY   START  STOP  MILES  PURPOSE
# 492  6/28/2016 23:34  6/28/2016 23:59  Business  Durham  Cary    9.9  Meeting

# %%
df.drop_duplicates()
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                   STOP    MILES          PURPOSE
# 0          Fort Pierce      5.1   Meal/Entertain
# 1          Fort Pierce      5.0              NaN
# 2          Fort Pierce      4.8  Errand/Supplies
# 3          Fort Pierce      4.7          Meeting
# 4      West Palm Beach     63.7   Customer Visit
# ...                ...      ...              ...
# 1151  Unknown Location      3.9   Temporary Site
# 1152  Unknown Location     16.2          Meeting
# 1153           Gampaha      6.4   Temporary Site
# 1154         Ilukwatta     48.2   Temporary Site
# 1155               NaN  12204.7              NaN
#
# [1155 rows x 7 columns]

# %%
# Renameing of features
df.rename(columns={
    'START_DATE': 'start_date',
    'END_DATE': 'end_date',
    'CATEGORY': 'category',
    'START' : 'start',
    'STOP' : 'stop',
    'MILES' : 'miles',
    'PURPOSE' : 'purpose'
}, inplace=True)

# %%
print(f"{Fore.RED}Null value in data: \n.{Style.RESET_ALL}")
df.isnull().sum()
# Out:
# Null value in data:
# .
# start_date      0
# end_date        1
# category        1
# start           1
# stop            1
# miles           0
# purpose       503
# dtype: int64

# %%
df['purpose']=df['purpose'].fillna('Missing')
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# start_date    0
# end_date      0
# category      0
# start         0
# stop          0
# miles         0
# purpose       0
# dtype: int64

# %% [markdown]
# # Feature Engineering 🔍

# %%
df['start_date'] = pd.to_datetime(df['start_date'], errors='coerce')
df['end_date'] = pd.to_datetime(df['end_date'], errors='coerce')

# %%
#creating new feature for better analysis and accuracy
from datetime import datetime
df['date']=pd.DatetimeIndex(df['start_date']).date
df['time']=pd.DatetimeIndex(df['start_date']).hour

# %%
df.head()
# Out:
#            start_date            end_date  category        start  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               stop  miles          purpose        date  time
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01  21.0
# 1      Fort Pierce    5.0          Missing  2016-01-02   1.0
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02  20.0
# 3      Fort Pierce    4.7          Meeting  2016-01-05  17.0
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06  14.0

# %%
# Create new features
# df["year"] = df['start_date'].dt.year  # Extract year from start_date
# df["day_name"] = df['start_date'].dt.day_name()  # Extract day name from start_date

# Categorize time into periods: Night, Morning, Afternoon, Evening
time_periods = [0, 6, 12, 18, 24]
labels = ['Night', 'Morning', 'Afternoon', 'Evening']

# Check if 'hour' can be accessed (only valid for non-NaT values)
df['time_label'] = pd.cut(df['start_date'].dt.hour, bins=time_periods, labels=labels, right=False)


# Calculate duration in minutes
df['duration'] = (df['end_date'] - df['start_date']).dt.total_seconds() / 60

# %%
df.head()
# Out:
#            start_date            end_date  category        start  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               stop  miles          purpose        date  time time_label  \
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01  21.0    Evening
# 1      Fort Pierce    5.0          Missing  2016-01-02   1.0      Night
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02  20.0    Evening
# 3      Fort Pierce    4.7          Meeting  2016-01-05  17.0  Afternoon
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06  14.0  Afternoon
#
#    duration
# 0       6.0
# 1      12.0
# 2      13.0
# 3      14.0
# 4      67.0

# %%
print(f'{Fore.BLACK}The New Data \n .{Style.RESET_ALL}')
df
# Out:
# The New Data
#  .
#               start_date            end_date  category             start  \
# 0    2016-01-01 21:11:00 2016-01-01 21:17:00  Business       Fort Pierce
# 1    2016-01-02 01:25:00 2016-01-02 01:37:00  Business       Fort Pierce
# 2    2016-01-02 20:25:00 2016-01-02 20:38:00  Business       Fort Pierce
# 3    2016-01-05 17:31:00 2016-01-05 17:45:00  Business       Fort Pierce
# 4    2016-01-06 14:42:00 2016-01-06 15:49:00  Business       Fort Pierce
# ...                  ...                 ...       ...               ...
# 1150                 NaT                 NaT  Business           Kar?chi
# 1151                 NaT                 NaT  Business           Kar?chi
# 1152                 NaT                 NaT  Business  Unknown Location
# 1153                 NaT                 NaT  Business        Katunayake
# 1154                 NaT                 NaT  Business           Gampaha
#
#                   stop  miles          purpose        date  time time_label  \
# 0          Fort Pierce    5.1   Meal/Entertain  2016-01-01  21.0    Evening
# 1          Fort Pierce    5.0          Missing  2016-01-02   1.0      Night
# 2          Fort Pierce    4.8  Errand/Supplies  2016-01-02  20.0    Evening
# 3          Fort Pierce    4.7          Meeting  2016-01-05  17.0  Afternoon
# 4      West Palm Beach   63.7   Customer Visit  2016-01-06  14.0  Afternoon
# ...                ...    ...              ...         ...   ...        ...
# 1150           Kar?chi    0.7          Meeting         NaT   NaN        NaN
# 1151  Unknown Location    3.9   Temporary Site         NaT   NaN        NaN
# 1152  Unknown Location   16.2          Meeting         NaT   NaN        NaN
# 1153           Gampaha    6.4   Temporary Site         NaT   NaN        NaN
# 1154         Ilukwatta   48.2   Temporary Site         NaT   NaN        NaN
#
#       duration
# 0          6.0
# 1         12.0
# 2         13.0
# 3         14.0
# 4         67.0
# ...        ...
# 1150       NaN
# 1151       NaN
# 1152       NaN
# 1153       NaN
# 1154       NaN
#
# [1155 rows x 11 columns]

# %% [markdown]
#  # Data Visualization

# %%
plt.figure(figsize=(20,7))
plt.subplot(1,2,1)
sns.countplot(x=df['category'])
plt.xticks(rotation=45)
plt.title('Value counts of Features :Category')
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.countplot(x=df['purpose'])
plt.title("Value Counts of Feature: PURPOSE")
plt.xticks(rotation=45)
plt.show()

# %%
sns.countplot(x=df['time_label'])
plt.title("Value Counts of Feature: TIME LABEL")
plt.xticks(rotation=45)
plt.show()

# %%
# plt.figure(figsize=(12,10))
# sns.countplot(x=df['month'])
# plt.title("Value Counts of Feature: MONTH")
# plt.xticks(rotation=45)
# plt.show()

# %%
df['month']=pd.DatetimeIndex(df['start_date']).month
month_label={1.0:'jan',2.0:'feb',3.0:'mar',4.0:'april',5.0:'may',6.0:'june',7.0:'july',8.0:'aug',9.0:'sept',10.0:'oct',11.0:'nov',12.0:'dec'}
df['month']=df.month.map(month_label)
mon=df.month.value_counts()

# %%
df1=pd.DataFrame({
    'month':mon.values,
    'value count':df.groupby('month',sort=False)['miles'].max()
    
})

p=sns.lineplot(data=df1)
p.set(xlabel='month',ylabel='value count')
plt.show()

# %%
df.head()
# Out:
#            start_date            end_date  category        start  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               stop  miles          purpose        date  time time_label  \
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01  21.0    Evening
# 1      Fort Pierce    5.0          Missing  2016-01-02   1.0      Night
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02  20.0    Evening
# 3      Fort Pierce    4.7          Meeting  2016-01-05  17.0  Afternoon
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06  14.0  Afternoon
#
#    duration month
# 0       6.0   jan
# 1      12.0   jan
# 2      13.0   jan
# 3      14.0   jan
# 4      67.0   jan

# %%
df['Day'] = df.start_date.dt.weekday
day_label={
    0:'Mon',1:'Tue',2:'Wed',3:'Thu',4:'Fri',5:'Sat',6:'Sun'
}
df['Day']=df['Day'].map(day_label)

# %%
df.head()
# Out:
#            start_date            end_date  category        start  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               stop  miles          purpose        date  time time_label  \
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01  21.0    Evening
# 1      Fort Pierce    5.0          Missing  2016-01-02   1.0      Night
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02  20.0    Evening
# 3      Fort Pierce    4.7          Meeting  2016-01-05  17.0  Afternoon
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06  14.0  Afternoon
#
#    duration month  Day
# 0       6.0   jan  Fri
# 1      12.0   jan  Sat
# 2      13.0   jan  Sat
# 3      14.0   jan  Tue
# 4      67.0   jan  Wed

# %%
day_label = df['Day'].value_counts()
sns.barplot(x=day_label.index,y=day_label)
plt.xlabel('Day')
plt.ylabel('value count')
plt.show()

# %%
plt.figure(figsize=(10,12))
sns.boxplot(df['miles'])
plt.show()

# %%
plt.figure(figsize=(10,12))
sns.distplot(df['miles'])
sns.distplot(df["miles"])
plt.title("Density PLot for Miles")
plt.show()

# %%
sns.distplot(df["duration"])
plt.title("Density PLot for Duration")
plt.show()

# %%
sns.kdeplot(df['miles'],label='Miles')
sns.kdeplot(df['duration'],label='Miles')
plt.title("Probability Density Function (PDF): Miles and Duration")
plt.xlabel('Miles vs duration')
plt.legend()
plt.show()

# %%
print(f"{Fore.CYAN}Outliers in data: \n.{Style.RESET_ALL}")
df = df[df['start_date'] != "Totals"]
df['start_date'] = pd.to_datetime(df['start_date'])
df.set_index('start_date', inplace=True)
daily_miles = df.resample('D')['miles'].sum()
plt.figure(figsize=(12, 6))
plt.plot(daily_miles.index, daily_miles.values)
plt.xlabel('Date')
plt.ylabel('Miles Driven')
plt.title('Miles Driven Over Time')
plt.show()
# Out:
# Outliers in data:
# .

# %%
# Calculate IQR for 'miles' feature
Q1_miles = np.percentile(df['miles'], 25)
Q3_miles = np.percentile(df['miles'], 75)
IQR_miles = Q3_miles - Q1_miles

# Calculate IQR for 'duration' feature
Q1_duration = np.percentile(df['duration'], 25)
Q3_duration = np.percentile(df['duration'], 75)
IQR_duration = Q3_duration - Q1_duration

# Define outlier boundaries
lower_bound_miles = Q1_miles - 1.5 * IQR_miles
upper_bound_miles = Q3_miles + 1.5 * IQR_miles

lower_bound_duration = Q1_duration - 1.5 * IQR_duration
upper_bound_duration = Q3_duration + 1.5 * IQR_duration
# Identify and deal with outliers
df['miles'] = np.where(df['miles'] < lower_bound_miles, lower_bound_miles, df['miles'])
df['miles'] = np.where(df['miles'] > upper_bound_miles, upper_bound_miles, df['miles'])

df['duration'] = np.where(df['duration'] < lower_bound_duration, lower_bound_duration, df['duration'])
df['duration'] = np.where(df['duration'] > upper_bound_duration, upper_bound_duration, df['duration'])

# %%
print(f"{Fore.RED}After Outliers Treatment: \n.{Style.RESET_ALL}")
daily_miles = df.resample('D')['miles'].sum()
plt.figure(figsize=(12, 6))
plt.plot(daily_miles.index, daily_miles.values)
plt.xlabel('Date')
plt.ylabel('Miles Driven')
plt.title('Miles Driven Over Time')
plt.show()
# Out:
# After Outliers Treatment:
# .
